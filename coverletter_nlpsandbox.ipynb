# %%
import docx

# %%
from textblob import TextBlob

from itertools import groupby

# %% [markdown]
# ## Experimenting with TextBlob

# %%
def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %%
text = getText('Cover_Letters/samplecoverletter_001.docx')

# %%
text = TextBlob(text)

# %%
text.tags
# Out:
# [('Ebony', 'NNP'),
#  ('Moore', 'NNP'),
#  ('123', 'CD'),
#  ('456-7891', 'CD'),
#  ('emoore', 'NN'),
#  ('@', 'NNP'),
#  ('email.com', 'NN'),
#  ('May', 'NNP'),
#  ('1', 'CD'),
#  ('2018', 'CD'),
#  ('Dear', 'NNP'),
#  ('Hiring', 'NNP'),
#  ('Manager', 'NNP'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('excited', 'JJ'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('applying', 'VBG'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('Data', 'NNP'),
#  ('Analyst', 'NNP'),
#  ('position', 'NN'),
#  ('at', 'IN'),
#  ('Cloud', 'NNP'),
#  ('Clearwater', 'NNP'),
#  ('As', 'IN'),
#  ('someone', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('lifetime', 'JJ'),
#  ('love', 'NN'),
#  ('of', 'IN'),
#  ('relational', 'JJ'),
#  ('mathematics', 'NNS'),
#  ('and', 'CC'),
#  ('pattern', 'JJ'),
#  ('recognition', 'NN'),
#  ('I', 'PRP'),
#  ('thrive', 'VBP'),
#  ('on', 'IN'),
#  ('digging', 'VBG'),
#  ('into', 'IN'),
#  ('complex', 'JJ'),
#  ('data', 'NNS'),
#  ('sets', 'NNS'),
#  ('and', 'CC'),
#  ('producing', 'VBG'),
#  ('insightful', 'JJ'),
#  ('data-driven', 'JJ'),
#  ('strategic', 'JJ'),
#  ('recommendations', 'NNS'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('eager', 'JJ'),
#  ('to', 'TO'),
#  ('turn', 'VB'),
#  ('my', 'PRP$'),
#  ('talent', 'NN'),
#  ('for', 'IN'),
#  ('analyzing', 'VBG'),
#  ('big', 'JJ'),
#  ('data', 'NNS'),
#  ('into', 'IN'),
#  ('actionable', 'JJ'),
#  ('growth', 'NN'),
#  ('strategies', 'NNS'),
#  ('for', 'IN'),
#  ('Cloud', 'NNP'),
#  ('Clearwater', 'NNP'),
#  ('During', 'IN'),
#  ('my', 'PRP$'),
#  ('previous', 'JJ'),
#  ('role', 'NN'),
#  ('at', 'IN'),
#  ('River', 'NNP'),
#  ('Tech', 'NNP'),
#  ('I', 'PRP'),
#  ('supported', 'VBD'),
#  ('our', 'PRP$'),
#  ('sales', 'NNS'),
#  ('marketing', 'NN'),
#  ('and', 'CC'),
#  ('executive', 'NN'),
#  ('teams', 'NNS'),
#  ('with', 'IN'),
#  ('recurring', 'VBG'),
#  ('market', 'NN'),
#  ('insight', 'JJ'),
#  ('reports', 'NNS'),
#  ('and', 'CC'),
#  ('ad', 'NN'),
#  ('hoc', 'NN'),
#  ('data', 'NNS'),
#  ('analysis', 'NN'),
#  ('I', 'PRP'),
#  ('pioneered', 'VBD'),
#  ('the', 'DT'),
#  ('use', 'NN'),
#  ('of', 'IN'),
#  ('predictive', 'JJ'),
#  ('modeling', 'VBG'),
#  ('techniques', 'NNS'),
#  ('to', 'TO'),
#  ('generate', 'VB'),
#  ('revenue', 'NN'),
#  ('forecasting', 'VBG'),
#  ('reports', 'NNS'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('high', 'JJ'),
#  ('degree', 'NN'),
#  ('of', 'IN'),
#  ('accuracy', 'NN'),
#  ('resulting', 'VBG'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('22', 'CD'),
#  ('%', 'NN'),
#  ('improvement', 'NN'),
#  ('in', 'IN'),
#  ('cash', 'NN'),
#  ('flow', 'NN'),
#  ('cycles', 'NNS'),
#  ('In', 'IN'),
#  ('addition', 'NN'),
#  ('to', 'TO'),
#  ('multiple', 'VB'),
#  ('commendations', 'NNS'),
#  ('from', 'IN'),
#  ('senior', 'JJ'),
#  ('leadership', 'NN'),
#  ('for', 'IN'),
#  ('developing', 'VBG'),
#  ('successful', 'JJ'),
#  ('Business', 'NNP'),
#  ('Intelligence', 'NNP'),
#  ('models', 'NNS'),
#  ('I', 'PRP'),
#  ('was', 'VBD'),
#  ('also', 'RB'),
#  ('nominated', 'VBN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('Rising', 'NNP'),
#  ('Star', 'NNP'),
#  ('Award', 'NNP'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('prestigious', 'JJ'),
#  ('2016', 'CD'),
#  ('Data', 'NNP'),
#  ('Analytics', 'NNP'),
#  ('&', 'CC'),
#  ('Insight', 'NNP'),
#  ('Awards', 'NNPS'),
#  ('With', 'IN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('eight', 'CD'),
#  ('years', 'NNS'),
#  ('of', 'IN'),
#  ('experience', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('professional', 'JJ'),
#  ('Data', 'NNP'),
#  ('Analyst', 'NNP'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('fluent', 'JJ'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('wide', 'JJ'),
#  ('variety', 'NN'),
#  ('of', 'IN'),
#  ('software', 'NN'),
#  ('and', 'CC'),
#  ('data', 'NN'),
#  ('management', 'NN'),
#  ('systems', 'NNS'),
#  ('ranging', 'VBG'),
#  ('from', 'IN'),
#  ('traditional', 'JJ'),
#  ('options', 'NNS'),
#  ('like', 'IN'),
#  ('Excel', 'NNP'),
#  ('and', 'CC'),
#  ('MySQL', 'NNP'),
#  ('to', 'TO'),
#  ('newer', 'VB'),
#  ('SaaS', 'NNP'),
#  ('systems', 'NNS'),
#  ('like', 'IN'),
#  ('Salesforce', 'NNP'),
#  ('and', 'CC'),
#  ('Infusionsoft', 'NNP'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('a', 'DT'),
#  ('working', 'JJ'),
#  ('knowledge', 'NN'),
#  ('of', 'IN'),
#  ('core', 'NN'),
#  ('programming', 'NN'),
#  ('skills', 'NNS'),
#  ('which', 'WDT'),
#  ('has', 'VBZ'),
#  ('allowed', 'VBN'),
#  ('me', 'PRP'),
#  ('to', 'TO'),
#  ('develop', 'VB'),
#  ('over', 'IN'),
#  ('100', 'CD'),
#  ('custom', 'NN'),
#  ('reporting', 'NN'),
#  ('solutions', 'NNS'),
#  ('within', 'IN'),
#  ('each', 'DT'),
#  ('of', 'IN'),
#  ('these', 'DT'),
#  ('data', 'NNS'),
#  ('systems', 'NNS'),
#  ('and', 'CC'),
#  ('deliver', 'VB'),
#  ('unique', 'JJ'),
#  ('innovative', 'JJ'),
#  ('reports', 'NNS'),
#  ('to', 'TO'),
#  ('executive', 'VB'),
#  ('leadership', 'NN'),
#  ('Thank', 'NNP'),
#  ('you', 'PRP'),
#  ('for', 'IN'),
#  ('your', 'PRP$'),
#  ('time', 'NN'),
#  ('and', 'CC'),
#  ('consideration', 'NN'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('looking', 'VBG'),
#  ('forward', 'RB'),
#  ('to', 'TO'),
#  ('learning', 'VBG'),
#  ('more', 'JJR'),
#  ('details', 'NNS'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('Data', 'NNP'),
#  ('Analyst', 'NNP'),
#  ('position', 'NN'),
#  ('and', 'CC'),
#  ('about', 'IN'),
#  ('Cloud', 'NNP'),
#  ('Clearwater', 'NNP'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('thrilled', 'VBN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('opportunity', 'NN'),
#  ('to', 'TO'),
#  ('use', 'VB'),
#  ('my', 'PRP$'),
#  ('expertise', 'NN'),
#  ('and', 'CC'),
#  ('experience', 'NN'),
#  ('to', 'TO'),
#  ('identify', 'VB'),
#  ('key', 'JJ'),
#  ('data', 'NNS'),
#  ('patterns', 'NNS'),
#  ('and', 'CC'),
#  ('develop', 'VB'),
#  ('predictive', 'JJ'),
#  ('models', 'NNS'),
#  ('to', 'TO'),
#  ('help', 'VB'),
#  ('Cloud', 'NNP'),
#  ('Clearwater', 'NNP'),
#  ('achieve', 'VBP'),
#  ('its', 'PRP$'),
#  ('strategic', 'JJ'),
#  ('and', 'CC'),
#  ('operational', 'JJ'),
#  ('goals', 'NNS'),
#  ('Sincerely', 'RB'),
#  ('Ebony', 'NNP'),
#  ('Moore', 'NNP')]

# %%
phrases = text.noun_phrases

# %%
print(phrases)
# Out:
# ['ebony moore', 'emoore @ email.com', 'may', 'dear', 'data analyst', 'cloud clearwater', 'relational mathematics', 'pattern recognition', 'complex data', 'strategic recommendations', 'big data', 'actionable growth strategies', 'cloud clearwater', 'previous role', 'tech', 'executive teams', 'market insight reports', 'data analysis', 'generate revenue', 'high degree', '% improvement', 'cash flow cycles', 'multiple commendations', 'senior leadership', 'successful business', 'intelligence', 'rising', 'star award', 'data', 'analytics', 'insight awards', 'data analyst', 'wide variety', 'data management systems', 'traditional options', 'excel', 'mysql', 'saas', 'salesforce', 'infusionsoft', 'data systems', 'innovative reports', 'executive leadership', 'thank', 'data analyst', 'cloud clearwater', 'identify key data patterns', 'predictive models', 'cloud clearwater', 'operational goals', 'sincerely', 'ebony moore']

# %%
phrases_list = []
for phrase in phrases:
    phrases_list.append(phrase)

# %%
b = [len(list(group)) for key, group in groupby(phrases)]

# %%
import pandas
from collections import Counter
letter_counts = Counter(phrases)
df = pandas.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar')
